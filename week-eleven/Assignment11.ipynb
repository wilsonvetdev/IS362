# %%
import config

import pandas as pd
import requests, json
from pprint import pprint
from bs4 import BeautifulSoup

# %%
api_key = config.API_KEY
api_secret = config.API_SECRET

# %%
url = f'https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json?api-key={api_key}'

resp = requests.get(url)
data = json.loads(resp.text)

# %%
pprint(data)
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights '
#               'Reserved.',
#  'num_results': 33528,
#  'results': [{'age_group': '',
#               'author': 'Diana Gabaldon',
#               'contributor': 'by Diana Gabaldon',
#               'contributor_note': '',
#               'description': 'The author of the Outlander novels gives tips on '
#                              'writing sex scenes, drawing on examples from the '
#                              'books.',
#               'isbns': [{'isbn10': '0399178570', 'isbn13': '9780399178573'}],
#               'price': '0.00',
#               'publisher': 'Dell',
#               'ranks_history': [{'asterisk': 0,
#                                  'bestsellers_date': '2016-08-20',
#                                  'dagger': 0,
#                                  'display_name': 'Advice, How-To & '
#                                                  'Miscellaneous',
#                                  'list_name': 'Advice How-To and Miscellaneous',
#                                  'primary_isbn10': '0399178570',
#                                  'primary_isbn13': '9780399178573',
#                                  'published_date': '2016-09-04',
#                                  'rank': 8,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 1}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '"I GIVE YOU MY BODY ..."'},
#              {'age_group': '',
#               'author': 'Annette Gordon-Reed and Peter S Onuf',
#               'contributor': 'by Annette Gordon-Reed and Peter S. Onuf',
#               'contributor_note': '',
#               'description': 'A character study that attempts to make sense of '
#                              'Jefferson’s contradictions.',
#               'isbns': [{'isbn10': '0871404427', 'isbn13': '9780871404428'}],
#               'price': '0.00',
#               'publisher': 'Liveright',
#               'ranks_history': [{'asterisk': 1,
#                                  'bestsellers_date': '2016-04-16',
#                                  'dagger': 0,
#                                  'display_name': 'Hardcover Nonfiction',
#                                  'list_name': 'Hardcover Nonfiction',
#                                  'primary_isbn10': '0871404427',
#                                  'primary_isbn13': '9780871404428',
#                                  'published_date': '2016-05-01',
#                                  'rank': 16,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 1}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '"MOST BLESSED OF THE PATRIARCHS"'},
#              {'age_group': '',
#               'author': 'Gary Vaynerchuk',
#               'contributor': 'by Gary Vaynerchuk',
#               'contributor_note': '',
#               'description': 'The entrepreneur expands on subjects addressed '
#                              'on his Internet show, like marketing, management '
#                              'and social media.',
#               'isbns': [{'isbn10': '0062273124', 'isbn13': '9780062273123'},
#                         {'isbn10': '0062273132', 'isbn13': '9780062273130'}],
#               'price': '0.00',
#               'publisher': 'HarperCollins',
#               'ranks_history': [{'asterisk': 0,
#                                  'bestsellers_date': '2016-03-26',
#                                  'dagger': 1,
#                                  'display_name': 'Business',
#                                  'list_name': 'Business Books',
#                                  'primary_isbn10': '0062273124',
#                                  'primary_isbn13': '9780062273123',
#                                  'published_date': '2016-04-10',
#                                  'rank': 5,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0},
#                                 {'asterisk': 0,
#                                  'bestsellers_date': '2016-03-12',
#                                  'dagger': 1,
#                                  'display_name': 'Advice, How-To & '
#                                                  'Miscellaneous',
#                                  'list_name': 'Advice How-To and Miscellaneous',
#                                  'primary_isbn10': '0062273124',
#                                  'primary_isbn13': '9780062273123',
#                                  'published_date': '2016-03-27',
#                                  'rank': 6,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 1}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '#ASKGARYVEE'},
#              {'age_group': '',
#               'author': 'Sophia Amoruso',
#               'contributor': 'by Sophia Amoruso',
#               'contributor_note': '',
#               'description': 'An online fashion retailer traces her path to '
#                              'success.',
#               'isbns': [{'isbn10': '039916927X', 'isbn13': '9780399169274'},
#                         {'isbn10': '1591847931', 'isbn13': '9781591847939'}],
#               'price': '0.00',
#               'publisher': 'Portfolio/Penguin/Putnam',
#               'ranks_history': [{'asterisk': 0,
#                                  'bestsellers_date': '2016-02-27',
#                                  'dagger': 0,
#                                  'display_name': 'Business',
#                                  'list_name': 'Business Books',
#                                  'primary_isbn10': '1591847931',
#                                  'primary_isbn13': '9781591847939',
#                                  'published_date': '2016-03-13',
#                                  'rank': 8,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0},
#                                 {'asterisk': 0,
#                                  'bestsellers_date': '2016-01-02',
#                                  'dagger': 0,
#                                  'display_name': 'Business',
#                                  'list_name': 'Business Books',
#                                  'primary_isbn10': '1591847931',
#                                  'primary_isbn13': '9781591847939',
#                                  'published_date': '2016-01-17',
#                                  'rank': 9,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0},
#                                 {'asterisk': 0,
#                                  'bestsellers_date': '2015-11-28',
#                                  'dagger': 0,
#                                  'display_name': 'Business',
#                                  'list_name': 'Business Books',
#                                  'primary_isbn10': '1591847931',
#                                  'primary_isbn13': '9781591847939',
#                                  'published_date': '2015-12-13',
#                                  'rank': 9,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0},
#                                 {'asterisk': 0,
#                                  'bestsellers_date': '2015-10-31',
#                                  'dagger': 0,
#                                  'display_name': 'Business',
#                                  'list_name': 'Business Books',
#                                  'primary_isbn10': '1591847931',
#                                  'primary_isbn13': '9781591847939',
#                                  'published_date': '2015-11-15',
#                                  'rank': 8,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0},
#                                 {'asterisk': 0,
#                                  'bestsellers_date': '2014-10-25',
#                                  'dagger': 0,
#                                  'display_name': 'Business',
#                                  'list_name': 'Business Books',
#                                  'primary_isbn10': '039916927X',
#                                  'primary_isbn13': '9780399169274',
#                                  'published_date': '2014-11-09',
#                                  'rank': 10,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0},
#                                 {'asterisk': 0,
#                                  'bestsellers_date': '2014-09-27',
#                                  'dagger': 0,
#                                  'display_name': 'Business',
#                                  'list_name': 'Business Books',
#                                  'primary_isbn10': '039916927X',
#                                  'primary_isbn13': '9780399169274',
#                                  'published_date': '2014-10-12',
#                                  'rank': 8,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '#GIRLBOSS'},
#              {'age_group': '',
#               'author': 'Kristin Hensley and Jen Smedley',
#               'contributor': 'by Kristin Hensley and Jen Smedley',
#               'contributor_note': '',
#               'description': '',
#               'isbns': [{'isbn10': '006285769X', 'isbn13': '9780062857699'}],
#               'price': '0.00',
#               'publisher': 'HarperOne',
#               'ranks_history': [{'asterisk': 0,
#                                  'bestsellers_date': '2019-04-06',
#                                  'dagger': 1,
#                                  'display_name': 'Advice, How-To & '
#                                                  'Miscellaneous',
#                                  'list_name': 'Advice How-To and Miscellaneous',
#                                  'primary_isbn10': '006285769X',
#                                  'primary_isbn13': '9780062857699',
#                                  'published_date': '2019-04-21',
#                                  'rank': 10,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 1}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '#IMOMSOHARD'},
#              {'age_group': '',
#               'author': 'David Hogg and Lauren Hogg',
#               'contributor': 'by David Hogg and Lauren Hogg',
#               'contributor_note': '',
#               'description': 'Students from Marjory Stoneman Douglas High '
#                              "School describe the Valentine's Day mass "
#                              'shooting and outline ways to prevent similar '
#                              'incidents.',
#               'isbns': [{'isbn10': '198480183X', 'isbn13': '9781984801838'}],
#               'price': '0.00',
#               'publisher': 'Random House',
#               'ranks_history': [{'asterisk': 0,
#                                  'bestsellers_date': '2018-06-23',
#                                  'dagger': 0,
#                                  'display_name': 'Paperback Nonfiction',
#                                  'list_name': 'Paperback Nonfiction',
#                                  'primary_isbn10': '198480183X',
#                                  'primary_isbn13': '9781984801838',
#                                  'published_date': '2018-07-08',
#                                  'rank': 9,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 1}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '#NEVERAGAIN'},
#              {'age_group': '',
#               'author': 'Chris Guillebeau',
#               'contributor': 'by Chris Guillebeau',
#               'contributor_note': '',
#               'description': 'How to build a profitable start up for $100 or '
#                              'less and be your own boss.',
#               'isbns': [{'isbn10': '0307951529', 'isbn13': '9780307951526'}],
#               'price': '23.00',
#               'publisher': 'Crown Business',
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '$100 STARTUP'},
#              {'age_group': '',
#               'author': 'Christopher Steiner',
#               'contributor': 'by Christopher Steiner',
#               'contributor_note': '',
#               'description': '',
#               'isbns': [],
#               'price': '0.00',
#               'publisher': 'Grand Central',
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '$20 PER GALLON'},
#              {'age_group': None,
#               'author': 'Steve Monroe',
#               'contributor': None,
#               'contributor_note': None,
#               'description': None,
#               'isbns': [{'isbn10': '0786867302', 'isbn13': '9780786867301'}],
#               'price': '0.00',
#               'publisher': None,
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': None,
#                            'book_review_link': '',
#                            'first_chapter_link': None,
#                            'sunday_review_link': 'https://www.nytimes.com/2001/07/29/books/books-in-brief-fiction-poetry-319660.html'}],
#               'title': "'57, Chicago"},
#              {'age_group': None,
#               'author': "GEOFFREY STOKES, KEN TUCKER' 'ED WARD",
#               'contributor': None,
#               'contributor_note': None,
#               'description': None,
#               'isbns': [{'isbn10': '0671630687', 'isbn13': '9780671630683'}],
#               'price': '0.00',
#               'publisher': None,
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': None,
#                            'book_review_link': '',
#                            'first_chapter_link': None,
#                            'sunday_review_link': 'https://www.nytimes.com/1986/12/28/books/three-chord-music-in-a-three-piece-suit.html'}],
#               'title': "'ROCK OF AGES: ''ROLLING STONE'' HISTORY OF ROCK AND "
#                        "ROLL'"},
#              {'age_group': None,
#               'author': 'KATE TELTSCHER',
#               'contributor': None,
#               'contributor_note': None,
#               'description': None,
#               'isbns': [{'isbn10': '0374217009', 'isbn13': '9780374217006'}],
#               'price': '0.00',
#               'publisher': None,
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': None,
#                            'book_review_link': '',
#                            'first_chapter_link': None,
#                            'sunday_review_link': 'https://www.nytimes.com/2007/04/22/books/review/Stuart.t.html'}],
#               'title': "'THE HIGH ROAD TO CHINA: GEORGE BOGLE, THE PANCHEN "
#                        "LAMA AND THE FIRST BRITISH EXPEDITION TO TIBET'"},
#              {'age_group': '',
#               'author': 'Sharon Sala',
#               'contributor': 'by Sharon Sala',
#               'contributor_note': '',
#               'description': '',
#               'isbns': [{'isbn10': '0778314278', 'isbn13': '9780778314271'}],
#               'price': '0.00',
#               'publisher': 'Harlequin Mira',
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': "'TIL DEATH"},
#              {'age_group': '',
#               'author': 'Amanda Quick',
#               'contributor': 'by Amanda Quick',
#               'contributor_note': '',
#               'description': 'A matchmaker in Victorian England turns to a '
#                              'crime novelist for help when she starts '
#                              'receiving a series of disturbingly personalized '
#                              'trinkets.',
#               'isbns': [{'isbn10': '069819361X', 'isbn13': '9780698193611'},
#                         {'isbn10': '039917446X', 'isbn13': '9780399174469'}],
#               'price': '0.00',
#               'publisher': 'Berkley',
#               'ranks_history': [{'asterisk': 0,
#                                  'bestsellers_date': '2016-04-23',
#                                  'dagger': 0,
#                                  'display_name': 'E-Book Fiction',
#                                  'list_name': 'E-Book Fiction',
#                                  'primary_isbn10': '069819361X',
#                                  'primary_isbn13': '9780698193611',
#                                  'published_date': '2016-05-08',
#                                  'rank': 9,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 1},
#                                 {'asterisk': 0,
#                                  'bestsellers_date': '2016-04-23',
#                                  'dagger': 0,
#                                  'display_name': 'Combined Print & E-Book '
#                                                  'Fiction',
#                                  'list_name': 'Combined Print and E-Book '
#                                               'Fiction',
#                                  'primary_isbn10': '069819361X',
#                                  'primary_isbn13': '9780698193611',
#                                  'published_date': '2016-05-08',
#                                  'rank': 15,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 1}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': "'TIL DEATH DO US PART"},
#              {'age_group': None,
#               'author': 'Naomi Schaefer Riley',
#               'contributor': None,
#               'contributor_note': None,
#               'description': None,
#               'isbns': [{'isbn10': '0199873747', 'isbn13': '9780199873746'}],
#               'price': '0.00',
#               'publisher': None,
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': None,
#                            'book_review_link': '',
#                            'first_chapter_link': None,
#                            'sunday_review_link': 'https://www.nytimes.com/2013/05/26/books/review/til-faith-do-us-part-by-naomi-schaefer-riley.html'}],
#               'title': "'Til Faith Do Us Part: How Interfaith Marriage is "
#                        'Transforming America'},
#              {'age_group': '',
#               'author': 'Ron Carr',
#               'contributor': 'by Robyn Carr',
#               'contributor_note': '',
#               'description': 'Two classic holiday stories — "Under the '
#                              'Christmas Tree" (2009) and "Midnight '
#                              'Confessions" (2010) — plus the novella "Backward '
#                              'Glance" (1991).',
#               'isbns': [{'isbn10': '0778316645', 'isbn13': '9780778316640'}],
#               'price': '0.00',
#               'publisher': 'Harlequin Mira',
#               'ranks_history': [{'asterisk': 0,
#                                  'bestsellers_date': '2014-11-15',
#                                  'dagger': 0,
#                                  'display_name': 'Paperback Mass-Market '
#                                                  'Fiction',
#                                  'list_name': 'Mass Market Paperback',
#                                  'primary_isbn10': '0778316645',
#                                  'primary_isbn13': '9780778316640',
#                                  'published_date': '2014-11-30',
#                                  'rank': 18,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0},
#                                 {'asterisk': 1,
#                                  'bestsellers_date': '2014-11-01',
#                                  'dagger': 0,
#                                  'display_name': 'Paperback Mass-Market '
#                                                  'Fiction',
#                                  'list_name': 'Mass Market Paperback',
#                                  'primary_isbn10': '0778316645',
#                                  'primary_isbn13': '9780778316640',
#                                  'published_date': '2014-11-16',
#                                  'rank': 6,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 1}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': "'TIS THE SEASON"},
#              {'age_group': '',
#               'author': 'Action Bronson with Rachel Wharton',
#               'contributor': 'by Action Bronson with Rachel Wharton',
#               'contributor_note': '',
#               'description': '',
#               'isbns': [{'isbn10': '1419726552', 'isbn13': '9781419726552'}],
#               'price': '0.00',
#               'publisher': 'Abrams',
#               'ranks_history': [{'asterisk': 0,
#                                  'bestsellers_date': '2017-09-16',
#                                  'dagger': 1,
#                                  'display_name': 'Advice, How-To & '
#                                                  'Miscellaneous',
#                                  'list_name': 'Advice How-To and Miscellaneous',
#                                  'primary_isbn10': '1419726552',
#                                  'primary_isbn13': '9781419726552',
#                                  'published_date': '2017-10-01',
#                                  'rank': 9,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 1}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': "------, THAT'S DELICIOUS"},
#              {'age_group': None,
#               'author': 'James Carville',
#               'contributor': None,
#               'contributor_note': None,
#               'description': None,
#               'isbns': [{'isbn10': '0684857340', 'isbn13': '9780684857343'}],
#               'price': '0.00',
#               'publisher': None,
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': None,
#                            'book_review_link': '',
#                            'first_chapter_link': None,
#                            'sunday_review_link': 'https://www.nytimes.com/1998/10/18/books/preaching-to-the-converted.html'}],
#               'title': '...and the Horse He Rode In On: The People V. Kenneth '
#                        'Starr'},
#              {'age_group': '',
#               'author': 'Hamazaki Tatsuya',
#               'contributor': 'by Hamazaki Tatsuya',
#               'contributor_note': '',
#               'description': 'This series, set in the future, is about an '
#                              'online, multiplayer game run amok. This volume '
#                              'concludes the tale.',
#               'isbns': [],
#               'price': '10.99',
#               'publisher': 'TOKYOPOP',
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '.HACK G.U.   , VOL. 5'},
#              {'age_group': None,
#               'author': 'David Adams Richards',
#               'contributor': None,
#               'contributor_note': None,
#               'description': None,
#               'isbns': [{'isbn10': '0671003542', 'isbn13': '9780671003548'}],
#               'price': '0.00',
#               'publisher': None,
#               'ranks_history': [],
#               'reviews': [{'article_chapter_link': None,
#                            'book_review_link': '',
#                            'first_chapter_link': None,
#                            'sunday_review_link': 'https://www.nytimes.com/1997/08/31/books/books-in-brief-fiction-747866.html'}],
#               'title': '1 Ragged Ridge Road'},
#              {'age_group': '',
#               'author': 'Patricia Schultz',
#               'contributor': 'by Patricia Schultz',
#               'contributor_note': '',
#               'description': 'A guide for traveling the world; second edition '
#                              'updated with new entries.',
#               'isbns': [{'isbn10': '0761156860', 'isbn13': '9780761156864'},
#                         {'isbn10': '0761104844', 'isbn13': '9780761104841'}],
#               'price': '0.00',
#               'publisher': 'Workman',
#               'ranks_history': [{'asterisk': 0,
#                                  'bestsellers_date': '2015-03-28',
#                                  'dagger': 0,
#                                  'display_name': 'Travel',
#                                  'list_name': 'Travel',
#                                  'primary_isbn10': '0761156860',
#                                  'primary_isbn13': '9780761156864',
#                                  'published_date': '2015-04-12',
#                                  'rank': 10,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0},
#                                 {'asterisk': 0,
#                                  'bestsellers_date': '2015-02-28',
#                                  'dagger': 0,
#                                  'display_name': 'Travel',
#                                  'list_name': 'Travel',
#                                  'primary_isbn10': '0761156860',
#                                  'primary_isbn13': '9780761156864',
#                                  'published_date': '2015-03-15',
#                                  'rank': 8,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0},
#                                 {'asterisk': 0,
#                                  'bestsellers_date': '2014-12-27',
#                                  'dagger': 0,
#                                  'display_name': 'Travel',
#                                  'list_name': 'Travel',
#                                  'primary_isbn10': '0761156860',
#                                  'primary_isbn13': '9780761156864',
#                                  'published_date': '2015-01-11',
#                                  'rank': 12,
#                                  'ranks_last_week': None,
#                                  'weeks_on_list': 0}],
#               'reviews': [{'article_chapter_link': '',
#                            'book_review_link': '',
#                            'first_chapter_link': '',
#                            'sunday_review_link': ''}],
#               'title': '1,000 PLACES TO SEE BEFORE YOU DIE'}],
#  'status': 'OK'}
