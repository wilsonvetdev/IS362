# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_table('auto-mpg.data', header=None)

data['car name'] = data[1]
data = data.drop(columns = [1])

# %%
data
# Out:
#                       car name   mpg cylinders displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0         8        307.0       130.0
# 1            buick skylark 320  15.0         8        350.0       165.0
# 2           plymouth satellite  18.0         8        318.0       150.0
# 3                amc rebel sst  16.0         8        304.0       150.0
# 4                  ford torino  17.0         8        302.0       140.0
# ..                         ...   ...       ...          ...         ...
# 393            ford mustang gl  27.0         4        140.0        86.0
# 394                  vw pickup  44.0         4        97.00        52.0
# 395              dodge rampage  32.0         4        135.0        84.0
# 396                ford ranger  28.0         4        120.0        79.0
# 397                 chevy s-10  31.0         4        119.0        82.0
#
#      weight acceleration model_year origin
# 0    3504.0         12.0         70    USA
# 1    3693.0         11.5         70    USA
# 2    3436.0         11.0         70    USA
# 3    3433.0         12.0         70    USA
# 4    3449.0         10.5         70    USA
# ..      ...          ...        ...    ...
# 393  2790.0         15.6         82    USA
# 394  2130.0         24.6         82   Asia
# 395  2295.0         11.6         82    USA
# 396  2625.0         18.6         82    USA
# 397  2720.0         19.4         82    USA
#
# [398 rows x 9 columns]

# %% [markdown]
# <h1>Auto Dataset containing vehicle data from USA, Asia, and Eruope</h1>
# <p>The database had no headers. I made a new column from data[1], which contained vehicle names, and dropped the column to make it more tidy.</p>
# <p>data[0] had all the other important data we needed and below is how I split up the column to make new columns.</p>

# %%
mpg_array = []
cylinders_array = []
displacement_array = []
horsepower_array = []
weight_array = []
acceleration_array = []
model_year_array = []
origin_array = []

for i in range(len(data)):
    splitted_array = data[0][i].split(' ')
    clean_array = [item for item in splitted_array if item]
    mpg_array.append(clean_array[0])
    cylinders_array.append(clean_array[1])
    displacement_array.append(clean_array[2])
    horsepower_array.append(clean_array[3])
    weight_array.append(clean_array[4])
    acceleration_array.append(clean_array[5])
    model_year_array.append(clean_array[6])
    origin_array.append(clean_array[7])

# %%
data['mpg'] = mpg_array
data['cylinders'] = cylinders_array
data['displacement'] = displacement_array
data['horsepower'] = horsepower_array
data['weight'] = weight_array
data['acceleration'] = acceleration_array
data['model_year'] = model_year_array
data['origin'] = origin_array

# %%
data
# Out:
#                                                      0  \
# 0    18.0   8   307.0      130.0      3504.      12...
# 1    15.0   8   350.0      165.0      3693.      11...
# 2    18.0   8   318.0      150.0      3436.      11...
# 3    16.0   8   304.0      150.0      3433.      12...
# 4    17.0   8   302.0      140.0      3449.      10...
# ..                                                 ...
# 393  27.0   4   140.0      86.00      2790.      15...
# 394  44.0   4   97.00      52.00      2130.      24...
# 395  32.0   4   135.0      84.00      2295.      11...
# 396  28.0   4   120.0      79.00      2625.      18...
# 397  31.0   4   119.0      82.00      2720.      19...
#
#                       car name   mpg cylinders displacement horsepower weight  \
# 0    chevrolet chevelle malibu  18.0         8        307.0      130.0  3504.
# 1            buick skylark 320  15.0         8        350.0      165.0  3693.
# 2           plymouth satellite  18.0         8        318.0      150.0  3436.
# 3                amc rebel sst  16.0         8        304.0      150.0  3433.
# 4                  ford torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 393            ford mustang gl  27.0         4        140.0      86.00  2790.
# 394                  vw pickup  44.0         4        97.00      52.00  2130.
# 395              dodge rampage  32.0         4        135.0      84.00  2295.
# 396                ford ranger  28.0         4        120.0      79.00  2625.
# 397                 chevy s-10  31.0         4        119.0      82.00  2720.
#
#     acceleration model_year origin
# 0           12.0         70      1
# 1           11.5         70      1
# 2           11.0         70      1
# 3           12.0         70      1
# 4           10.5         70      1
# ..           ...        ...    ...
# 393         15.6         82      1
# 394         24.6         82      2
# 395         11.6         82      1
# 396         18.6         82      1
# 397         19.4         82      1
#
# [398 rows x 10 columns]

# %%
data = data.drop(columns=[0])

# %%
data
# Out:
#                       car name   mpg cylinders displacement horsepower weight  \
# 0    chevrolet chevelle malibu  18.0         8        307.0      130.0  3504.
# 1            buick skylark 320  15.0         8        350.0      165.0  3693.
# 2           plymouth satellite  18.0         8        318.0      150.0  3436.
# 3                amc rebel sst  16.0         8        304.0      150.0  3433.
# 4                  ford torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 393            ford mustang gl  27.0         4        140.0      86.00  2790.
# 394                  vw pickup  44.0         4        97.00      52.00  2130.
# 395              dodge rampage  32.0         4        135.0      84.00  2295.
# 396                ford ranger  28.0         4        120.0      79.00  2625.
# 397                 chevy s-10  31.0         4        119.0      82.00  2720.
#
#     acceleration model_year origin
# 0           12.0         70      1
# 1           11.5         70      1
# 2           11.0         70      1
# 3           12.0         70      1
# 4           10.5         70      1
# ..           ...        ...    ...
# 393         15.6         82      1
# 394         24.6         82      2
# 395         11.6         82      1
# 396         18.6         82      1
# 397         19.4         82      1
#
# [398 rows x 9 columns]

# %%
def convert_to_country(code):
    if code == '1':
        return 'USA'
    elif code == '2':
        return 'Asia'
    elif code == '3':
        return 'Europe'

# %%
data['origin'] = data['origin'].apply(convert_to_country)

# %%
data
# Out:
#                       car name   mpg cylinders displacement horsepower weight  \
# 0    chevrolet chevelle malibu  18.0         8        307.0      130.0  3504.
# 1            buick skylark 320  15.0         8        350.0      165.0  3693.
# 2           plymouth satellite  18.0         8        318.0      150.0  3436.
# 3                amc rebel sst  16.0         8        304.0      150.0  3433.
# 4                  ford torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 393            ford mustang gl  27.0         4        140.0      86.00  2790.
# 394                  vw pickup  44.0         4        97.00      52.00  2130.
# 395              dodge rampage  32.0         4        135.0      84.00  2295.
# 396                ford ranger  28.0         4        120.0      79.00  2625.
# 397                 chevy s-10  31.0         4        119.0      82.00  2720.
#
#     acceleration model_year origin
# 0           12.0         70    USA
# 1           11.5         70    USA
# 2           11.0         70    USA
# 3           12.0         70    USA
# 4           10.5         70    USA
# ..           ...        ...    ...
# 393         15.6         82    USA
# 394         24.6         82   Asia
# 395         11.6         82    USA
# 396         18.6         82    USA
# 397         19.4         82    USA
#
# [398 rows x 9 columns]

# %%
data.dtypes
# Out:
# car name        object
# mpg             object
# cylinders       object
# displacement    object
# horsepower      object
# weight          object
# acceleration    object
# model_year      object
# origin          object
# dtype: object

# %%
data['horsepower'] = data['horsepower'].replace(['?'], np.nan)

# %%
data.isna().sum()
# Out:
# car name        0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
data['horsepower'] = pd.to_numeric(data['horsepower'])

# %%
data.dtypes
# Out:
# car name         object
# mpg              object
# cylinders        object
# displacement     object
# horsepower      float64
# weight           object
# acceleration     object
# model_year       object
# origin           object
# dtype: object

# %%
sns.countplot(x = data['cylinders'], order = data['cylinders'].value_counts().index)

plt.show()

# %%
data['weight'] = pd.to_numeric(data['weight'])
horsepower = data['horsepower']
weight = data['weight']

plt.plot(weight, horsepower, 'o')
plt.title('Relationship between horsepower and weight of vehicle')
plt.xlabel('weight')
plt.ylabel('horsepower')
plt.show()

# %%
usa_data = data[data['origin'] == 'USA']
asia_data = data[data['origin'] == 'Asia']
europe_data = data[data['origin'] == 'Europe']

all_data_sum = len(data)

pie_chart_data = [len(usa_data)/all_data_sum, len(asia_data)/all_data_sum, len(europe_data)/all_data_sum]

plt.subplot(1, 2, 1)
plt.pie(pie_chart_data, labels=['USA', 'Asia', 'Europe'])

plt.subplot(1, 2, 2)
plt.bar(['USA', 'Asia', 'Europe'], pie_chart_data)
plt.subplots_adjust(wspace=0.45)
plt.show()
