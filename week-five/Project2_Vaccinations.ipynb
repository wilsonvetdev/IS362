# %%
import pandas as pd

# %% [markdown]
# <h1>Vaccinations and Countries dataset</h1>

# %%
vaccinations_df = pd.read_csv('country_vaccinations.csv')

# %% [markdown]
# <h3>Finding the latest available data they have based on the date column</h3>

# %%
vaccinations_df.sort_values('date', ascending=False).head(10)
# Out:
#          country iso_code        date  total_vaccinations  people_vaccinated  \
# 4677    Zimbabwe      ZWE  2021-03-01             21456.0            21456.0
# 2312       Italy      ITA  2021-03-01           4354008.0          2942345.0
# 998   Costa Rica      CRI  2021-03-01            149812.0           103695.0
# 2247      Israel      ISR  2021-03-01           8211997.0          4772078.0
# 2736    Malaysia      MYS  2021-03-01             25252.0                NaN
# 2764    Maldives      MDV  2021-03-01            117115.0                NaN
# 1291     Ecuador      ECU  2021-03-01             42114.0            35886.0
# 1060     Croatia      HRV  2021-03-01            213068.0           153085.0
# 4082    Slovenia      SVN  2021-03-01            174493.0           123087.0
# 1678     Germany      DEU  2021-03-01           6394364.0          4234952.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# <h3>Counting the number of countries in this dataset</h3>

# %%
len(vaccinations_df.country.unique())
# Out:
# 118

# %% [markdown]
# <h3>Let's see how many countries have record based on the latest available data here</h3>

# %%
vaccinations_df[vaccinations_df.date == '2021-03-01']
# Out:
#                    country iso_code        date  total_vaccinations  \
# 173              Argentina      ARG  2021-03-01           1049169.0
# 188              Australia      AUS  2021-03-01             33702.0
# 239                Austria      AUT  2021-03-01            670208.0
# 329                Bahrain      BHR  2021-03-01            301103.0
# 596                 Brazil      BRA  2021-03-01           8465403.0
# 659               Bulgaria      BGR  2021-03-01            223539.0
# 729                 Canada      CAN  2021-03-01           1954728.0
# 859                  Chile      CHL  2021-03-01           3490572.0
# 930               Colombia      COL  2021-03-01            149133.0
# 998             Costa Rica      CRI  2021-03-01            149812.0
# 1060               Croatia      HRV  2021-03-01            213068.0
# 1177               Czechia      CZE  2021-03-01            674040.0
# 1291               Ecuador      ECU  2021-03-01             42114.0
# ...

# %% [markdown]
# <h3>There are 118 countries with data in this dataset, but only 39 has data on 2021-03-01</h3>

# %%
vaccinations_df[vaccinations_df.date == '2021-03-01'].count()
# Out:
# country                                39
# iso_code                               39
# date                                   39
# total_vaccinations                     39
# people_vaccinated                      32
# people_fully_vaccinated                26
# daily_vaccinations_raw                 28
# daily_vaccinations                     39
# total_vaccinations_per_hundred         39
# people_vaccinated_per_hundred          32
# people_fully_vaccinated_per_hundred    26
# daily_vaccinations_per_million         39
# vaccines                               39
# source_name                            39
# source_website                         39
# dtype: int64

# %% [markdown]
# <h3>For countries with available data on 2021-03-01, I would like to see total_vaccinations sorted</h3>

# %%
latest_vaccinations_df = vaccinations_df[vaccinations_df.date == '2021-03-01']
latest_vaccinations_df.sort_values('total_vaccinations', ascending=False)
# Out:
#                    country iso_code        date  total_vaccinations  \
# 4579         United States      USA  2021-03-01          76899987.0
# 4337                Turkey      TUR  2021-03-01           8774718.0
# 596                 Brazil      BRA  2021-03-01           8465403.0
# 2247                Israel      ISR  2021-03-01           8211997.0
# 1678               Germany      DEU  2021-03-01           6394364.0
# 4429  United Arab Emirates      ARE  2021-03-01           6028417.0
# 3679                Russia      RUS  2021-03-01           5238966.0
# 2312                 Italy      ITA  2021-03-01           4354008.0
# 859                  Chile      CHL  2021-03-01           3490572.0
# 3414                Poland      POL  2021-03-01           3383426.0
# 2899                Mexico      MEX  2021-03-01           2526863.0
# 729                 Canada      CAN  2021-03-01           1954728.0
# 173              Argentina      ARG  2021-03-01           1049169.0
# ...

# %% [markdown]
# <h3>
#     Going back to the original DataFrame, I want to see how many records are missing values in any of the columns. In this case, we can see that more than 3000 rows are missing data in some columns by checking the shape.
# </h3>

# %%
vaccinations_df.dropna(how='any').count()
# Out:
# country                                1381
# iso_code                               1381
# date                                   1381
# total_vaccinations                     1381
# people_vaccinated                      1381
# people_fully_vaccinated                1381
# daily_vaccinations_raw                 1381
# daily_vaccinations                     1381
# total_vaccinations_per_hundred         1381
# people_vaccinated_per_hundred          1381
# people_fully_vaccinated_per_hundred    1381
# daily_vaccinations_per_million         1381
# vaccines                               1381
# source_name                            1381
# source_website                         1381
# dtype: int64

# %%
vaccinations_df.count()
# Out:
# country                                4678
# iso_code                               4366
# date                                   4678
# total_vaccinations                     3054
# people_vaccinated                      2595
# people_fully_vaccinated                1746
# daily_vaccinations_raw                 2576
# daily_vaccinations                     4518
# total_vaccinations_per_hundred         3054
# people_vaccinated_per_hundred          2595
# people_fully_vaccinated_per_hundred    1746
# daily_vaccinations_per_million         4518
# vaccines                               4678
# source_name                            4678
# source_website                         4678
# dtype: int64

# %% [markdown]
# <h3>Checking the total amount of vaccinees given on 2021-03-01</h3>

# %%
latest_vaccinations_df['total_vaccinations'].sum()
# Out:
# 143348088.0
