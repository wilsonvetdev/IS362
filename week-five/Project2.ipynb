# %%
import pandas as pd

# %%
vaccinations_df = pd.read_csv('country_vaccinations.csv')

# %%
vaccinations_df[vaccinations_df.country == 'United States']
# Out:
#             country iso_code        date  total_vaccinations  \
# 4508  United States      USA  2020-12-20            556208.0
# 4509  United States      USA  2020-12-21            614117.0
# 4510  United States      USA  2020-12-22                 NaN
# 4511  United States      USA  2020-12-23           1008025.0
# 4512  United States      USA  2020-12-24                 NaN
# ...             ...      ...         ...                 ...
# 4575  United States      USA  2021-02-25          68274117.0
# 4576  United States      USA  2021-02-26          70454064.0
# 4577  United States      USA  2021-02-27          72806180.0
# 4578  United States      USA  2021-02-28          75236003.0
# 4579  United States      USA  2021-03-01          76899987.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 4508           556208.0                      NaN                     NaN
# 4509           614117.0                      NaN                 57909.0
# ...
